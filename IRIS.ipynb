# %% [markdown]
# # Pandas is a package in python to manipulate the data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the Data with read_csv function

# %%
iris=pd.read_csv(r'C:\Users\hp\Desktop\dataset\IRIS.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Pandas Dataframes: DataFrame is an object for data manipulation. It isa 2D tabular structure, where every row is a dataset entry and columns represent features of data.

# %%
type(iris) # DATAFRAME: 2D table with rows and columns
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # We can have a look to first few rows of the table using head function

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df=iris.copy()

# %% [markdown]
# # Head function

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %% [markdown]
# # If we don't give no. of rows then it will print 5 rows

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Shape function

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df.dtypes) # shows type of data
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # How to change name of columns

# %%
df.columns=['sepal___length','sepal___width','petal___lenght','petal___width','speciesss']

# %%
df.columns
# Out:
# Index(['sepal___length', 'sepal___width', 'petal___lenght', 'petal___width',
#        'speciesss'],
#       dtype='object')

# %% [markdown]
# # Describe Function

# %%
df.describe()
# Out:
#        sepal___length  sepal___width  petal___lenght  petal___width
# count      150.000000     150.000000      150.000000     150.000000
# mean         5.843333       3.054000        3.758667       1.198667
# std          0.828066       0.433594        1.764420       0.763161
# min          4.300000       2.000000        1.000000       0.100000
# 25%          5.100000       2.800000        1.600000       0.300000
# 50%          5.800000       3.000000        4.350000       1.300000
# 75%          6.400000       3.300000        5.100000       1.800000
# max          7.900000       4.400000        6.900000       2.500000

# %% [markdown]
# # Accessing particular column

# %%
df.sepal___length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal___length, Length: 150, dtype: float64

# %%
df["sepal___length"] # another method to access
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal___length, Length: 150, dtype: float64

# %% [markdown]
# # isnull function(helps to check null entries)

# %%
df.isnull()
# Out:
#      sepal___length  sepal___width  petal___lenght  petal___width  speciesss
# 0             False          False           False          False      False
# 1             False          False           False          False      False
# 2             False          False           False          False      False
# 3             False          False           False          False      False
# 4             False          False           False          False      False
# ..              ...            ...             ...            ...        ...
# 145           False          False           False          False      False
# 146           False          False           False          False      False
# 147           False          False           False          False      False
# 148           False          False           False          False      False
# 149           False          False           False          False      False
#
# [150 rows x 5 columns]

# %% [markdown]
# # we can use sum with isnull to check that how many null values are present in any column

# %%
df.isnull().sum()
# Out:
# sepal___length    0
# sepal___width     0
# petal___lenght    0
# petal___width     0
# speciesss         0
# dtype: int64

# %% [markdown]
# # Accessing particular data using iloc function

# %%
df.iloc[1:4, 2:3] # 1:4 means 3 rows(1st to 3rd) and 2:3 means 1 column(2nd)
# Out:
#    petal___lenght
# 1             1.4
# 2             1.3
# 3             1.5

# %%
iris # Changes via df will not reflect in iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Manipulating Data in Data Frame

# %% [markdown]
# # Drop by label

# %%
# columns : headers
# rows: labels 
df.drop(0)
df.head()  # here this will not remove the 0th row.
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa

# %%
a=df.drop(0)
a.head()
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa
# 5             5.4            3.9             1.7            0.4  Iris-setosa

# %%
# labels ae fixed but positions are not fixed. # indesing stays same

# %%
a=df.drop(3)  # drop by level
a.head()
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa
# 5             5.4            3.9             1.7            0.4  Iris-setosa

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.drop(4, inplace=True) # dropping by level 3 levels sticks to the row # only indexing changes
df.head()
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 5             5.4            3.9             1.7            0.4  Iris-setosa

# %%
df.index
# Out:
# Int64Index([  0,   1,   2,   3,   5,   6,   7,   8,   9,  10,
#             ...
#             140, 141, 142, 143, 144, 145, 146, 147, 148, 149],
#            dtype='int64', length=149)

# %%
a.index
# Out:
# Int64Index([  0,   1,   2,   4,   5,   6,   7,   8,   9,  10,
#             ...
#             140, 141, 142, 143, 144, 145, 146, 147, 148, 149],
#            dtype='int64', length=149)

# %% [markdown]
# # drop by position

# %%
# drop by position
df.index[5], df.index[3]
# Out:
# (6, 3)

# %%
df.drop(df.index[0], inplace=True)
df.head()
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 5             5.4            3.9             1.7            0.4  Iris-setosa
# 6             4.6            3.4             1.4            0.3  Iris-setosa

# %%
df.drop(df.index[4], inplace=True)
df.head()
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 5             5.4            3.9             1.7            0.4  Iris-setosa
# 7             5.0            3.4             1.5            0.2  Iris-setosa

# %%
df.sepal___length>3
# Out:
# 1      True
# 2      True
# 3      True
# 5      True
# 7      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: sepal___length, Length: 147, dtype: bool

# %%
df[df.sepal___length>5]   # this will give you only those rows for which the condition is true
# Out:
#      sepal___length  sepal___width  petal___lenght  petal___width  \
# 5               5.4            3.9             1.7            0.4
# 10              5.4            3.7             1.5            0.2
# 14              5.8            4.0             1.2            0.2
# 15              5.7            4.4             1.5            0.4
# 16              5.4            3.9             1.3            0.4
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#           speciesss
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
df[df.speciesss=='Iris-setosa']
# Out:
#     sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 1              4.9            3.0             1.4            0.2  Iris-setosa
# 2              4.7            3.2             1.3            0.2  Iris-setosa
# 3              4.6            3.1             1.5            0.2  Iris-setosa
# 5              5.4            3.9             1.7            0.4  Iris-setosa
# 7              5.0            3.4             1.5            0.2  Iris-setosa
# 8              4.4            2.9             1.4            0.2  Iris-setosa
# 9              4.9            3.1             1.5            0.1  Iris-setosa
# 10             5.4            3.7             1.5            0.2  Iris-setosa
# 11             4.8            3.4             1.6            0.2  Iris-setosa
# 12             4.8            3.0             1.4            0.1  Iris-setosa
# 13             4.3            3.0             1.1            0.1  Iris-setosa
# ...

# %%
df[df.speciesss=='Iris-setosa'].describe()
# Out:
#        sepal___length  sepal___width  petal___lenght  petal___width
# count       47.000000      47.000000       47.000000      47.000000
# mean         5.012766       3.412766        1.468085       0.244681
# std          0.358510       0.392105        0.178285       0.109958
# min          4.300000       2.300000        1.000000       0.100000
# 25%          4.800000       3.100000        1.400000       0.200000
# 50%          5.000000       3.400000        1.500000       0.200000
# 75%          5.200000       3.700000        1.600000       0.300000
# max          5.800000       4.400000        1.900000       0.600000

# %%
print(df.head())
# Out:
#    sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 5             5.4            3.9             1.7            0.4  Iris-setosa
# 7             5.0            3.4             1.5            0.2  Iris-setosa

# %%
df.iloc[0]    # used for positions
# Out:
# sepal___length            4.9
# sepal___width               3
# petal___lenght            1.4
# petal___width             0.2
# speciesss         Iris-setosa
# Name: 1, dtype: object

# %%
df.loc[7] # used for levels
# Out:
# sepal___length              5
# sepal___width             3.4
# petal___lenght            1.5
# petal___width             0.2
# speciesss         Iris-setosa
# Name: 7, dtype: object

# %% [markdown]
# # ADD A ROW

# %%
df.loc[0]=[1,2,3,4,"Hansika"] # df.loc[0]=[1,2,3,4,"Hansika"] 

df.loc[0]
# Out:
# sepal___length          1
# sepal___width           2
# petal___lenght          3
# petal___width           4
# speciesss         Hansika
# Name: 0, dtype: object

# %%
df.head(10)
# Out:
#     sepal___length  sepal___width  petal___lenght  petal___width    speciesss
# 1              4.9            3.0             1.4            0.2  Iris-setosa
# 2              4.7            3.2             1.3            0.2  Iris-setosa
# 3              4.6            3.1             1.5            0.2  Iris-setosa
# 5              5.4            3.9             1.7            0.4  Iris-setosa
# 7              5.0            3.4             1.5            0.2  Iris-setosa
# 8              4.4            2.9             1.4            0.2  Iris-setosa
# 9              4.9            3.1             1.5            0.1  Iris-setosa
# 10             5.4            3.7             1.5            0.2  Iris-setosa
# 11             4.8            3.4             1.6            0.2  Iris-setosa
# 12             4.8            3.0             1.4            0.1  Iris-setosa

# %%
df.tail()
# Out:
#      sepal___length  sepal___width  petal___lenght  petal___width  \
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
# 0               1.0            2.0             3.0            4.0
#
#           speciesss
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 0           Hansika

# %% [markdown]
# # Way to reset index

# %%
df.index
# Out:
# Int64Index([  1,   2,   3,   5,   7,   8,   9,  10,  11,  12,
#             ...
#             141, 142, 143, 144, 145, 146, 147, 148, 149,   0],
#            dtype='int64', length=148)

# %%
df.reset_index() # increasing sequence but also giving index
# Out:
#      index  sepal___length  sepal___width  petal___lenght  petal___width  \
# 0        1             4.9            3.0             1.4            0.2
# 1        2             4.7            3.2             1.3            0.2
# 2        3             4.6            3.1             1.5            0.2
# 3        5             5.4            3.9             1.7            0.4
# 4        7             5.0            3.4             1.5            0.2
# ..     ...             ...            ...             ...            ...
# 143    146             6.3            2.5             5.0            1.9
# 144    147             6.5            3.0             5.2            2.0
# 145    148             6.2            3.4             5.4            2.3
# 146    149             5.9            3.0             5.1            1.8
# 147      0             1.0            2.0             3.0            4.0
#
#           speciesss
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
df.reset_index(drop=True) # this will not print the index
# Out:
#      sepal___length  sepal___width  petal___lenght  petal___width  \
# 0               4.9            3.0             1.4            0.2
# 1               4.7            3.2             1.3            0.2
# 2               4.6            3.1             1.5            0.2
# 3               5.4            3.9             1.7            0.4
# 4               5.0            3.4             1.5            0.2
# ..              ...            ...             ...            ...
# 143             6.3            2.5             5.0            1.9
# 144             6.5            3.0             5.2            2.0
# 145             6.2            3.4             5.4            2.3
# 146             5.9            3.0             5.1            1.8
# 147             1.0            2.0             3.0            4.0
#
#           speciesss
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 143  Iris-virginica
# ...

# %%
df.reset_index(drop=True)
df.index
# Out:
# Int64Index([  1,   2,   3,   5,   7,   8,   9,  10,  11,  12,
#             ...
#             141, 142, 143, 144, 145, 146, 147, 148, 149,   0],
#            dtype='int64', length=148)

# %%
df.describe()
# Out:
#        sepal___width  petal___lenght  petal___width
# count     148.000000      148.000000     148.000000
# mean        3.037838        3.801351       1.237162
# std         0.440069        1.744729       0.789410
# min         2.000000        1.000000       0.100000
# 25%         2.800000        1.600000       0.300000
# 50%         3.000000        4.400000       1.300000
# 75%         3.300000        5.100000       1.800000
# max         4.400000        6.900000       4.000000

# %%
del df['sepal___width']

# %%
df.describe()
# Out:
#        petal___lenght  petal___width
# count      148.000000     148.000000
# mean         3.801351       1.237162
# std          1.744729       0.789410
# min          1.000000       0.100000
# 25%          1.600000       0.300000
# 50%          4.400000       1.300000
# 75%          5.100000       1.800000
# max          6.900000       4.000000

# %%
df.head()
# Out:
#    petal___lenght  petal___width    speciesss
# 1             1.4            0.2  Iris-setosa
# 2             1.3            0.2  Iris-setosa
# 3             1.5            0.2  Iris-setosa
# 5             1.7            0.4  Iris-setosa
# 7             1.5            0.2  Iris-setosa

# %%
df=iris.copy()
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # ADD A COLUMN

# %%
df["diff_petal_lenth_petal_width"]=df["petal_length"]-df["petal_width"]
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    diff_petal_lenth_petal_width
# 0                           1.2
# 1                           1.2
# 2                           1.1
# 3                           1.3
# 4                           1.2

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      diff_petal_lenth_petal_width
# 145                           2.9
# 146                           3.1
# 147                           3.2
# 148                           3.1
# 149                           3.3

# %%
df["abc"]=1
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      diff_petal_lenth_petal_width  abc
# 145                           2.9    1
# 146                           3.1    1
# 147                           3.2    1
# 148                           3.1    1
# 149                           3.3    1

# %% [markdown]
# # Handling NAN

# %%
df.iloc[2:4, 1:3]=np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          NaN           NaN          0.2  Iris-setosa
# 3           4.6          NaN           NaN          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 2                           1.1    1
# 3                           1.3    1
# 4                           1.2    1

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  \
# count    150.000000   148.000000    148.000000   150.000000
# mean       5.843333     3.052703      3.790541     1.198667
# std        0.828066     0.436349      1.754618     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
#        diff_petal_lenth_petal_width    abc
# count                    150.000000  150.0
# mean                       2.560000    1.0
# std                        1.050152    0.0
# min                        0.800000    1.0
# 25%                        1.400000    1.0
# 50%                        2.900000    1.0
# 75%                        3.300000    1.0
# max                        4.700000    1.0

# %%
df.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      diff_petal_lenth_petal_width  abc
# 0                             1.2    1
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          NaN           NaN          0.2  Iris-setosa
# 3           4.6          NaN           NaN          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 2                           1.1    1
# 3                           1.3    1
# 4                           1.2    1

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 4                           1.2    1
# 5                           1.3    1
# 6                           1.1    1

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           5.0          3.6           1.4          0.2  Iris-setosa
# 3           5.4          3.9           1.7          0.4  Iris-setosa
# 4           4.6          3.4           1.4          0.3  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 2                           1.2    1
# 3                           1.3    1
# 4                           1.1    1

# %%
df.iloc[2:4, 1:3]=np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           5.0          NaN           NaN          0.2  Iris-setosa
# 3           5.4          NaN           NaN          0.4  Iris-setosa
# 4           4.6          3.4           1.4          0.3  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 2                           1.2    1
# 3                           1.3    1
# 4                           1.1    1

# %%
df.sepal_width.fillna(df.sepal_width.mean(), inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1     3.500000           1.4          0.2  Iris-setosa
# 1           4.9     3.000000           1.4          0.2  Iris-setosa
# 2           5.0     3.043151           NaN          0.2  Iris-setosa
# 3           5.4     3.043151           NaN          0.4  Iris-setosa
# 4           4.6     3.400000           1.4          0.3  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 2                           1.2    1
# 3                           1.3    1
# 4                           1.1    1

# %%
df.petal_length.fillna(df.petal_length.mean(), inplace=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1     3.500000      1.400000          0.2  Iris-setosa
# 1           4.9     3.000000      1.400000          0.2  Iris-setosa
# 2           5.0     3.043151      3.821233          0.2  Iris-setosa
# 3           5.4     3.043151      3.821233          0.4  Iris-setosa
# 4           4.6     3.400000      1.400000          0.3  Iris-setosa
#
#    diff_petal_lenth_petal_width  abc
# 0                           1.2    1
# 1                           1.2    1
# 2                           1.2    1
# 3                           1.3    1
# 4                           1.1    1

# %%
a=df[df.species=='Iris-setosa']
a
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species  \
# 0            5.1     3.500000      1.400000          0.2  Iris-setosa
# 1            4.9     3.000000      1.400000          0.2  Iris-setosa
# 2            5.0     3.043151      3.821233          0.2  Iris-setosa
# 3            5.4     3.043151      3.821233          0.4  Iris-setosa
# 4            4.6     3.400000      1.400000          0.3  Iris-setosa
# 5            5.0     3.400000      1.500000          0.2  Iris-setosa
# 6            4.4     2.900000      1.400000          0.2  Iris-setosa
# 7            4.9     3.100000      1.500000          0.1  Iris-setosa
# 8            5.4     3.700000      1.500000          0.2  Iris-setosa
# 9            4.8     3.400000      1.600000          0.2  Iris-setosa
# 10           4.8     3.000000      1.400000          0.1  Iris-setosa
# 11           4.3     3.000000      1.100000          0.1  Iris-setosa
# ...

# %%
a.petal_length.mean()
# Out:
# 1.561301369863014
